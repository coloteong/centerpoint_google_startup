# %%
# import required packages
import requests
import json
import pandas as pd
# API key: AIzaSyDPRi8jxCGzccPR34SkCjnEOh8F6ZKK_q0

# %%
# function to get pure json data from url
def get_response_from_API(url):
    payload={}
    headers = {}
    response = requests.request("GET", url, headers=headers, data=payload)
    print(response.text)
    return(response.text)

# %%
# function to convert address to (lat, long) format
def get_coordinates_from_address(address_string):
    formatted_dict = json.loads(address_string)
    # this part so hardcoded .. TODO: try to fix if possible
    formatted_dict = formatted_dict['candidates'][0]
    formatted_dict = formatted_dict['geometry']
    location_coordinates = formatted_dict['location']
    latitude = location_coordinates['lat']
    longitude = location_coordinates['lng']
    return (latitude,longitude)

# %%
# function to get raw (x,y) value of initial centre point
def find_central_point(location_list):
    # location_list is a list of tuples (x,y) of coordinates
    total_x = 0
    total_y = 0
    count = 0
    for point in location_list:
        total_x += point[0]
        total_y += point[1]
        count += 1
    # return a tuple of (x,y) coordinates 
    return (total_x/count, total_y/count)

# %%
# function to use google API to get possible locations in json dictionary format
def find_candidate_google_locations(central_point, purpose):
    # first, make the url string from the given central_point
    # TODO: make radius a variable to include in for loop later
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=" + str(central_point[0]) + "%2C" + str(central_point[1]) + "&radius=50&type=" + str(purpose) + "&key=AIzaSyDPRi8jxCGzccPR34SkCjnEOh8F6ZKK_q0"
    print(url)
    payload={}
    headers = {}
    response = requests.request("GET", url, headers=headers, data=payload)
    candidate_locations = response.text
    print(candidate_locations.type())
    #formatted_candidate_locations = json.loads(candidate_locations)
    return candidate_locations

# %%
def determine_final_google_location(candidate_location_dict):
    # clean the dictionary to get a nice list of all locations
    # dataframe includes name, rating, operating hrs, address, image
    result_df = pd.DataFrame.from_dict(cand_loc['results'])
# Out:
#   File "C:\Users\colot\AppData\Local\Temp/ipykernel_15688/3772400612.py", line 4
#
#     ^
# IndentationError: expected an indented block

# %%
url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Museum%20of%20Contemporary%20Art%20Australia&inputtype=textquery&fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&key=AIzaSyDPRi8jxCGzccPR34SkCjnEOh8F6ZKK_q0"
result = get_response_from_API(url)
# Out:
# {
#    "candidates" : [
#       {
#          "formatted_address" : "140 George St, The Rocks NSW 2000, Australia",
#          "geometry" : {
#             "location" : {
#                "lat" : -33.8599358,
#                "lng" : 151.2090295
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : -33.85824377010728,
#                   "lng" : 151.2104386798927
#                },
#                "southwest" : {
#                   "lat" : -33.86094342989272,
#                   "lng" : 151.2077390201073
#                }
#             }
#          },
#          "name" : "Museum of Contemporary Art Australia",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "rating" : 4.4
#       }
#    ],
#    "status" : "OK"
# }

# %% [markdown]
# formatted_result = json.loads(result)
# formatted_result = formatted_result['candidates'][0]
# formatted_result = formatted_result['geometry']
# formatted_result = formatted_result['location']
# formatted_result

# %%
coordinates = get_coordinates_from_address(result)

# %%
find_central_point([coordinates])
# Out:
# (-33.8599358, 151.2090295)

# %%
cand_loc = find_google_location((-33.8599358, 151.2090295), "restaurant")
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-33.8599358%2C151.2090295&radius=50&type=restaurant&key=AIzaSyDPRi8jxCGzccPR34SkCjnEOh8F6ZKK_q0
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -33.8599319, 'lng': 151.2088484},
#     'viewport': {'northeast': {'lat': -33.85827476970849,
#       'lng': 151.2104715802915},
#      'southwest': {'lat': -33.86097273029149, 'lng': 151.2077736197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'Black and White Espresso Bar',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 811,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111665652996907271102">Black and White Espresso Bar</a>'],
#      'photo_reference': 'Aap_uED5xbiWoCIiX8k677DJSw_4Mp5tJVanIo82IIteT9t16T4Tp1uw74l0DAb6CAimrkjZcaHEiCIyQ2nXvM4D26X9UQtJb0V82PdS-OLWe10y-mEb7h5ilZeY7AOAplbQAb94xD73GzWiKhQ9JU8ug7hTA4grVDTgbokhLnsnns0AggKJ',
#      'width': 1440}],
#    'place_id': 'ChIJvzkaU0CuEmsRT104Qka5dYo',
#    'plus_code': {'compound_code': '46R5+2G The Rocks NSW, Australia',
#     'global_code': '4RRH46R5+2G'},
#    'rating': 4.7,
#    'reference': 'ChIJvzkaU0CuEmsRT104Qka5dYo',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'bar',
#     'meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 140,
#    'vicinity': '140 George Street, The Rocks'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -33.8601975, 'lng': 151.2091718},
#     'viewport': {'northeast': {'lat': -33.8583857697085,
#       'lng': 151.2105652802915},
#      'southwest': {'lat': -33.8610837302915, 'lng': 151.2078673197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Graze MCA',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109889719238494850173">Lester Mark</a>'],
#      'photo_reference': 'Aap_uECdVGf_AWw2WnWF5iK-JzJIKmeyWvrH_nVwXhLkR0uchE7y2Uy7SXG0U0b0wclQEAy33dVJVVlE-JB5_0Af9VhQa_iQy_w_Hfi-MFepIJEF22rqp9cyeVqTQyuD36fsR18G5Po3I-mo2YSJ-zhnuAIuaRZYs5QsjYbDM8Fi9KD2al3y',
#      'width': 4032}],
#    'place_id': 'ChIJE44x9kKuEmsROEbg1YEjaZ0',
#    'plus_code': {'compound_code': '46Q5+WM The Rocks NSW, Australia',
#     'global_code': '4RRH46Q5+WM'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJE44x9kKuEmsROEbg1YEjaZ0',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 240,
#    'vicinity': 'Museum of Contemporary Art Australia, Ground, 140 George Street, The Rocks'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -33.8596775, 'lng': 151.2092187},
#     'viewport': {'northeast': {'lat': -33.8581473197085,
#       'lng': 151.2106253302915},
#      'southwest': {'lat': -33.8608452802915, 'lng': 151.2079273697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#    'name': 'MCA Cafe',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 525,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114075921880747674515">MCA Cafe</a>'],
#      'photo_reference': 'Aap_uEByDIWw4Ivfeu26UCXvb0Sb5le6z3b3--qFLIzqh-1UARSy9r-OHUS8RXoP9KbIKydT8rrGyssi57WnbRIQVUMHqvoszxo221IqMfrF4Nw4K4_vW3OcxjuR8s3CpeSg2EsftkOaCqQfJJFrrmJlLlPl5CvVEUXvBAkapT3HIg4zkYfv',
#      'width': 700}],
#    'place_id': 'ChIJQ5BflEKuEmsRFSIJuEf7qE8',
#    'plus_code': {'compound_code': '46R5+4M The Rocks NSW, Australia',
#     'global_code': '4RRH46R5+4M'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJQ5BflEKuEmsRFSIJuEf7qE8',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 825,
#    'vicinity': '4/140 George Street, The Rocks'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -33.8597877, 'lng': 151.2085579},
#     'viewport': {'northeast': {'lat': -33.8584482697085,
#       'lng': 151.2099883302915},
#      'southwest': {'lat': -33.8611462302915, 'lng': 151.2072903697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'William Blue Dining',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104319526986226060892">William Blue Dining</a>'],
#      'photo_reference': 'Aap_uEA5xcX3l_p5KWhcPi4xWtKrnZB0k9wOT8kWsG-UMhT56q7zVlGlTtOcbLzZESSIvLBHpx-OQUj9K2VCYl9S83oe2Zlrt3Y51olk54bUC8LdkXsl-2i3pURe2oQ290b1urfmW_V-bCW2_No6YMa8IXAmalO4ot5Tq1ta2cZdxfxU6nMC',
#      'width': 1194}],
#    'place_id': 'ChIJfzzdc_KuEmsR6cJa1Cusa7o',
#    'plus_code': {'compound_code': '46R5+3C The Rocks NSW, Australia',
#     'global_code': '4RRH46R5+3C'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJfzzdc_KuEmsR6cJa1Cusa7o',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 370,
#    'vicinity': '107 George Street, The Rocks'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -33.8598253, 'lng': 151.2085429},
#     'viewport': {'northeast': {'lat': -33.85848636970852,
#       'lng': 151.2099775802915},
#      'southwest': {'lat': -33.86118433029151, 'lng': 151.2072796197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Phoebe Fast Food',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJvfbWkOSvEmsREz0Hfkg54nI',
#    'plus_code': {'compound_code': '46R5+3C The Rocks NSW, Australia',
#     'global_code': '4RRH46R5+3C'},
#    'reference': 'ChIJvfbWkOSvEmsREz0Hfkg54nI',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': '107 George Street, The Rocks'}],
#  'status': 'OK'}

# %%
import pandas as pd
dataframe_locations = pd.DataFrame.from_dict(cand_loc['results'])
dataframe_locations = dataframe_locations.drop(columns=['icon_background_color', 'plus_code', 'scope', 'user_ratings_total' ])
dataframe_locations
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': -33.8599319, 'lng': 151.2...
# 1     OPERATIONAL  {'location': {'lat': -33.8601975, 'lng': 151.2...
# 2     OPERATIONAL  {'location': {'lat': -33.8596775, 'lng': 151.2...
# 3     OPERATIONAL  {'location': {'lat': -33.8597877, 'lng': 151.2...
# 4     OPERATIONAL  {'location': {'lat': -33.8598253, 'lng': 151.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                   icon_mask_base_uri  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                            name        opening_hours  \
# 0  Black and White Espresso Bar   {'open_now': True}
# 1                     Graze MCA   {'open_now': True}
# 2                      MCA Cafe   {'open_now': True}
# 3           William Blue Dining   {'open_now': True}
# 4              Phoebe Fast Food  {'open_now': False}
#
#                                               photos  \
# 0  [{'height': 811, 'html_attributions': ['<a hre...
# 1  [{'height': 3024, 'html_attributions': ['<a hr...
# 2  [{'height': 525, 'html_attributions': ['<a hre...
# 3  [{'height': 1280, 'html_attributions': ['<a hr...
# 4                                                NaN
#
#                       place_id  rating                    reference  \
# 0  ChIJvzkaU0CuEmsRT104Qka5dYo     4.7  ChIJvzkaU0CuEmsRT104Qka5dYo
# 1  ChIJE44x9kKuEmsROEbg1YEjaZ0     4.2  ChIJE44x9kKuEmsROEbg1YEjaZ0
# 2  ChIJQ5BflEKuEmsRFSIJuEf7qE8     4.3  ChIJQ5BflEKuEmsRFSIJuEf7qE8
# 3  ChIJfzzdc_KuEmsR6cJa1Cusa7o     4.6  ChIJfzzdc_KuEmsR6cJa1Cusa7o
# 4  ChIJvfbWkOSvEmsREz0Hfkg54nI     NaN  ChIJvfbWkOSvEmsREz0Hfkg54nI
#
#                                                types  \
# 0  [meal_takeaway, cafe, bar, restaurant, food, p...
# 1  [restaurant, food, point_of_interest, establis...
# 2  [cafe, restaurant, food, point_of_interest, st...
# 3  [restaurant, food, point_of_interest, establis...
# 4  [restaurant, food, point_of_interest, establis...
#
#                                             vicinity  price_level
# 0                       140 George Street, The Rocks          NaN
# 1  Museum of Contemporary Art Australia, Ground, ...          2.0
# 2                     4/140 George Street, The Rocks          2.0
# 3                       107 George Street, The Rocks          2.0
# 4                       107 George Street, The Rocks          NaN
